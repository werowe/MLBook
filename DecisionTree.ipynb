# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.datasets import make_blobs

x,y = make_blobs(n_samples=100, n_features=3)
                 
clf = tree.DecisionTreeClassifier()

clf = clf.fit(x, y)

# %%
plt.figure(figsize= [8, 10])
tree.plot_tree(clf,fontsize=14)
# Out:
# [Text(178.56, 453.0, 'X[2] <= -6.677\ngini = 0.667\nsamples = 100\nvalue = [34, 33, 33]'),
#  Text(89.28, 271.8, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(267.84000000000003, 271.8, 'X[2] <= 1.211\ngini = 0.5\nsamples = 66\nvalue = [0, 33, 33]'),
#  Text(178.56, 90.59999999999997, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]'),
#  Text(357.12, 90.59999999999997, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]

# %%
y
# Out:
# array([2, 2, 0, 0, 2, 0, 0, 0, 2, 1, 2, 0, 0, 1, 2, 2, 0, 1, 1, 0, 1, 1,
#        0, 1, 0, 2, 0, 0, 2, 0, 2, 1, 2, 1, 0, 2, 2, 2, 0, 1, 2, 1, 2, 1,
#        1, 2, 1, 0, 0, 2, 2, 1, 1, 0, 0, 2, 1, 2, 0, 1, 1, 1, 2, 2, 2, 2,
#        2, 1, 0, 2, 0, 0, 1, 2, 0, 0, 1, 0, 0, 1, 1, 2, 1, 2, 1, 1, 0, 1,
#        0, 1, 2, 0, 2, 1, 1, 1, 0, 0, 0, 2])

# %%
x
# Out:
# array([[ -4.46065188,  -6.4944518 ,   5.52121682],
#        [ -3.81505102,  -2.99198226,   5.09465203],
#        [  7.03002858,  -5.08368717,  -9.86018268],
#        [  5.37722699,  -4.83812689,  -9.8746919 ],
#        [ -2.05919531,  -1.29351217,   3.97821907],
#        [  5.02286836,  -6.42049141, -11.26941882],
#        [  4.89119134,  -6.85284004, -10.61228707],
#        [  4.53047047,  -3.33927234, -10.01366762],
#        [ -0.76911932,  -4.05933732,   5.5258753 ],
#        [ -1.93890795,  -8.91508769,  -4.40441726],
#        [ -3.79296135,  -2.17644944,   5.48442187],
#        [  7.09775772,  -6.01956623,  -8.6396596 ],
#        [  4.46679171,  -4.53010885, -10.5301499 ],
#        [ -1.84832337,  -8.87091343,  -1.89129168],
#        [ -3.77134616,  -5.40292703,   4.51017992],
#        [ -3.18397703,  -2.62777859,   7.2084647 ],
#        [  4.48481817,  -5.79490029,  -8.61924066],
#        [ -2.2142569 ,  -9.44806474,  -4.62640148],
#        [ -1.34996926,  -9.05859101,  -3.25860631],
#        [  4.30994335,  -6.71585224,  -9.11564368],
#        [ -1.36843305,  -8.81031211,  -5.03361048],
#        [ -2.99132469,  -8.26053046,  -2.29002893],
#        [  7.28490481,  -4.83015708,  -8.79863641],
#        [ -2.03397664,  -8.70979626,  -3.63135842],
#        [  6.55535214,  -5.65607572,  -9.16097682],
#        [ -2.87631936,  -2.9753469 ,   5.81368648],
#        [  5.55955221,  -4.32307061,  -9.05423042],
#        [  5.45425042,  -5.55353246,  -9.97656257],
#        [ -2.34765431,  -3.86150355,   4.95603628],
#        [  5.23331089,  -4.26101938,  -8.42623995],
#        [ -3.21898129,  -3.41965054,   4.60143986],
#        [ -0.76527842,  -9.06537687,  -3.5559116 ],
#        [ -2.15671948,  -3.93320293,   4.48594824],
#        [ -0.96592111, -10.80223007,  -6.28310172],
#        [  4.14587909,  -6.54098504,  -8.37907783],
#        [ -2.16421338,  -3.96634986,   6.75545112],
#        [ -3.93708209,  -4.95459705,   5.92745058],
#        [ -3.56206363,  -3.9810358 ,   4.43495177],
#        [  6.28105904,  -7.06943323,  -9.10593339],
#        [ -0.23300785, -10.26962756,  -2.50154014],
#        [ -3.08590863,  -3.70896131,   4.51013335],
#        [ -1.64284825, -10.56017043,  -3.99214009],
#        [ -2.38931316,  -5.22623329,   4.4320033 ],
#        [ -2.68371577,  -9.65197647,  -4.60107886],
#        [ -0.62931559,  -8.97057443,  -3.8868231 ],
#        [ -2.15102332,  -5.26545721,   4.91403339],
#        [ -1.73376158, -10.22405588,  -3.96485203],
#        [  4.75570333,  -6.03421925,  -8.86068414],
#        [  5.62527236,  -6.86203296, -10.85713069],
#        [ -2.04336493,  -2.02600683,   5.99154342],
#        [ -2.938494  ,  -2.81145519,   4.46303926],
#        [ -0.19715495, -10.08551066,  -4.25504213],
#        [ -0.58210425,  -9.89577957,  -3.58254387],
#        [  6.82465354,  -5.08607567,  -7.61486605],
#        [  6.9215643 ,  -6.00598738,  -9.63327317],
#        [ -2.4715364 ,  -5.11065396,   6.44773502],
#        [ -1.5734496 ,  -9.71448494,  -5.46215185],
#        [ -1.85309474,  -5.73514047,   6.0290203 ],
#        [  5.53405344,  -3.65710111, -10.19620116],
#        [ -0.61836022,  -9.30326975,  -3.50123474],
#        [ -2.6996331 ,  -9.60345634,  -2.77088676],
#        [ -1.27245344, -11.77363619,  -4.2224539 ],
#        [ -3.00708885,  -3.58671377,   5.79362574],
#        [ -2.74626712,  -6.35892013,   6.10995335],
#        [ -2.48571632,  -1.09453563,   4.11398929],
#        [ -3.09448312,  -1.91413917,   6.15113268],
#        [ -2.61911772,  -1.62603431,   6.29510249],
#        [ -0.94027941,  -9.23833231,  -3.64864356],
#        [  5.76322529,  -4.76400924, -10.11718885],
#        [ -3.27529787,  -4.36218369,   5.25391996],
#        [  7.00068155,  -6.28300301, -10.4018905 ],
#        [  5.82319282,  -3.92472524, -10.0638609 ],
#        [ -2.21715614,  -9.6807504 ,  -3.0021013 ],
#        [ -2.62884149,  -2.33179868,   6.04770163],
#        [  3.35345019,  -4.79073694,  -8.96555347],
#        [  6.02861157,  -3.61194522,  -9.81754572],
#        [ -0.92087271, -10.51870975,  -4.55404341],
#        [  3.40209148,  -4.89134056,  -7.47183777],
#        [  5.55904029,  -7.96812584,  -8.72138212],
#        [ -0.39346835,  -7.92474556,  -3.68983994],
#        [ -1.78104696,  -8.86486264,  -3.78331451],
#        [ -1.63217966,  -5.8146298 ,   4.47002546],
#        [  0.27427055, -10.00197202,  -4.8527838 ],
#        [ -1.10591267,  -4.84351397,   5.63445371],
#        [ -1.83937638,  -9.47425543,  -3.85026738],
#        [ -0.78525978,  -7.28809122,  -1.5564911 ],
#        [  4.28773698,  -4.66441956, -10.09997872],
#        [  0.24337426,  -9.80028632,  -3.45587869],
#        [  5.75427854,  -5.95736578,  -9.81230635],
#        [ -0.94800942, -10.4353176 ,  -4.21661154],
#        [ -2.54452684,  -2.74604799,   6.56438867],
#        [  5.7745982 ,  -5.05040678,  -8.83727347],
#        [ -4.89754223,  -5.49630454,   6.51742568],
#        [ -0.86656397,  -8.60765986,  -2.64488058],
#        [  1.01702733,  -9.82372295,  -3.58624908],
#        [ -2.28397571,  -9.79716688,  -5.36449197],
#        [  6.64209952,  -5.44857913,  -7.9795714 ],
#        [  5.23003995,  -4.61354628,  -9.46788145],
#        [  6.10040972,  -5.9855022 ,  -7.07039181],
#        [ -0.75702453,  -4.98816216,   7.56778622]])
